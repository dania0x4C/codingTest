# %%
# 백준-style input()을 테스트용으로 흉내내기 위한 클래스
class InputMock:
    def __init__(self, text: str):
        # 사용자가 지정한 입력 문자열을 저장 (전체 문자열)
        self.source = text.strip()  # 앞뒤 공백 제거
        # 아직 줄 단위로 나누지는 않음 → 첫 호출 시 reset()으로 분리됨

    def reset(self):
        # 원본 문자열을 줄 단위 리스트로 변환
        self.lines = self.source.split('\n')
        # 현재 읽고 있는 줄 번호를 초기화
        self.current = 0

    def __call__(self):
        # 아직 reset된 적 없거나, 모든 줄을 다 읽었으면 자동 초기화
        if not hasattr(self, 'lines') or self.current >= len(self.lines):
            self.reset()
        # 현재 줄 반환 후, 다음 줄로 인덱스 이동
        line = self.lines[self.current]
        self.current += 1
        return line


# 테스트 입력 정의 (여러 줄 입력도 가능)
test_input = """
3
3
10 7 6
3
3 5 9
5
1 1 3 1 2
"""

# input()처럼 사용 가능하게 인스턴스 생성
input = InputMock(test_input)

# %%
import sys

T = int(input())
for _ in range(T):
    N = int(input())
    points = list(map(int, input().strip().split()))
    value = 0
    max_point = 0

    for i in range(len(points) - 1, -1, -1):
        max_point = max(points[i], max_point)

        if points[i]< max_point:
            value += max_point - points[i]
    print(value)
# Out:
# 0
# 10
# 5

# %% [markdown]
# 1. errorCase -> 1, 10, 1, 10 일때를 고려 못 함
# 2. 앞에서 시작했으면 저 방법이 안 통했는데 뒤에서 최고값인지 확인 후 빼는 방식이라 가능했음

# %%
# 백준-style input()을 테스트용으로 흉내내기 위한 클래스
class InputMock:
    def __init__(self, text: str):
        # 사용자가 지정한 입력 문자열을 저장 (전체 문자열)
        self.source = text.strip()  # 앞뒤 공백 제거
        # 아직 줄 단위로 나누지는 않음 → 첫 호출 시 reset()으로 분리됨

    def reset(self):
        # 원본 문자열을 줄 단위 리스트로 변환
        self.lines = self.source.split('\n')
        # 현재 읽고 있는 줄 번호를 초기화
        self.current = 0

    def __call__(self):
        # 아직 reset된 적 없거나, 모든 줄을 다 읽었으면 자동 초기화
        if not hasattr(self, 'lines') or self.current >= len(self.lines):
            self.reset()
        # 현재 줄 반환 후, 다음 줄로 인덱스 이동
        line = self.lines[self.current]
        self.current += 1
        return line


# 테스트 입력 정의 (여러 줄 입력도 가능)
test_input = """
5
3 1 4 3 2
"""

# input()처럼 사용 가능하게 인스턴스 생성
input = InputMock(test_input)

# %%
import sys

N = input()
person = list(map(int, input().strip().split()))

totalTime = 0
accumulatedTime = 0
person.sort()
for t in person:
    accumulatedTime += t 
    totalTime += accumulatedTime # 3 + 3+1 + 3+1+4 + 3+1+4+3 + 3+1+4+3+2 = 3 + 4 + 8 + 11 + 13

print(totalTime)
# Out:
# 32

# %%
# 백준-style input()을 테스트용으로 흉내내기 위한 클래스
class InputMock:
    def __init__(self, text: str):
        # 사용자가 지정한 입력 문자열을 저장 (전체 문자열)
        self.source = text.strip()  # 앞뒤 공백 제거
        # 아직 줄 단위로 나누지는 않음 → 첫 호출 시 reset()으로 분리됨

    def reset(self):
        # 원본 문자열을 줄 단위 리스트로 변환
        self.lines = self.source.split('\n')
        # 현재 읽고 있는 줄 번호를 초기화
        self.current = 0

    def __call__(self):
        # 아직 reset된 적 없거나, 모든 줄을 다 읽었으면 자동 초기화
        if not hasattr(self, 'lines') or self.current >= len(self.lines):
            self.reset()
        # 현재 줄 반환 후, 다음 줄로 인덱스 이동
        line = self.lines[self.current]
        self.current += 1
        return line


# 테스트 입력 정의 (여러 줄 입력도 가능)
test_input = """
55-50+40
"""

# input()처럼 사용 가능하게 인스턴스 생성
input = InputMock(test_input)

# %%
import sys

expression = input.strip().split('-')
result = 0
mCounter = 0
for e in expression:
    if mCounter % 2 == 0:
        chunk = list((map(int, e.split('+'))))
    else:
        result += int(e.split('-'))

    mCounter += 1

print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 3
#       1 import sys
# ----> 3 expression = input.strip().split()
#       4 result = 0
#       5 mCounter = 0
#
# AttributeError: 'InputMock' object has no attribute 'strip'
